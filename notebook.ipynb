# %% [markdown]
# # cool right :)

# %%
from data.extract.extract_flow import extract
df = extract()
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
from data.transform.transform_flow import transform
synthetic_df = transform(df) 
synthetic_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0             5.100000          3.500000           1.400000          0.200000
# 1             4.900000          3.000000           1.400000          0.200000
# 2             4.700000          3.200000           1.300000          0.200000
# 3             4.600000          3.100000           1.500000          0.200000
# 4             5.000000          3.600000           1.400000          0.200000
# ..                 ...               ...                ...               ...
# 244           6.300000          3.347453           5.810188          2.452547
# 245           6.891743          3.095872           5.104128          2.300000
# 246           7.656683          3.453467           6.656683          2.156683
# 247           6.058243          3.000000           4.941757          1.800000
# 248           6.400000          2.933010           5.555663          1.966990
#
#      sepal length/sepal width  sepal length/petal length  \
# 0                    1.457143                   3.642857
# 1                    1.633333                   3.500000
# 2                    1.468750                   3.615385
# 3                    1.483871                   3.066667
# 4                    1.388889                   3.571429
# ..                        ...                        ...
# 244                  1.882028                   1.084302
# 245                  2.226108                   1.350229
# 246                  2.217101                   1.150225
# 247                  2.019414                   1.225929
# 248                  2.182059                   1.151978
#
#      sepal length/petal width  sepal width/petal length  \
# 0                   25.500000                  2.500000
# 1                   24.500000                  2.142857
# 2                   23.500000                  2.461538
# 3                   23.000000                  2.066667
# 4                   25.000000                  2.571429
# ..                        ...                       ...
# 244                  2.568758                  0.576135
# 245                  2.996410                  0.606543
# 246                  3.550212                  0.518797
# 247                  3.365691                  0.607072
# 248                  3.253702                  0.527932
#
#      sepal width/petal width  petal length/petal width  target
# 0                  17.500000                  7.000000       0
# 1                  15.000000                  7.000000       0
# 2                  16.000000                  6.500000       0
# 3                  15.500000                  7.500000       0
# 4                  18.000000                  7.000000       0
# ..                       ...                       ...     ...
# 244                 1.364888                  2.369042       2
# 245                 1.346031                  2.219186       2
# 246                 1.601286                  3.086537       2
# 247                 1.666667                  2.745420       2
# 248                 1.491116                  2.824449       2
#
# [249 rows x 11 columns]
