# %% [markdown]
# # cool right :)

# %%
from data.extract.extract_flow import extract
df = extract()
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
from data.transform.transform_flow import transform
synthetic_df = transform(df) 
synthetic_df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  4.6               3.4                1.4               0.3
# 1                  5.4               3.9                1.3               0.4
# 2                  5.4               3.7                1.5               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  5.0               3.4                1.5               0.2
# ..                 ...               ...                ...               ...
# 226                6.3               2.7                4.9               1.8
# 227                7.6               3.0                6.6               2.1
# 228                6.0               2.2                5.0               1.5
# 229                6.8               3.0                5.5               2.1
# 230                6.8               3.0                5.5               2.1
#
# ...

# %%
from data.save.save_flow import save
save(synthetic_df)
# Out:
# True

# %%
from model.load.load_flow import load
df = load()
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  4.6               3.4                1.4               0.3
# 1                  5.4               3.9                1.3               0.4
# 2                  5.4               3.7                1.5               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  5.0               3.4                1.5               0.2
# ..                 ...               ...                ...               ...
# 226                6.3               2.7                4.9               1.8
# 227                7.6               3.0                6.6               2.1
# 228                6.0               2.2                5.0               1.5
# 229                6.8               3.0                5.5               2.1
# 230                6.8               3.0                5.5               2.1
#
# ...

# %%
from model.train.train_flow import create_model

create_model(df)
# Out:
# /workspaces/mlflow_be_easy/model/train/train_flow.py:54: ExperimentalWarning: WilcoxonPruner is experimental (supported from v3.6.0). The interface can change in the future.
#   pruner = WilcoxonPruner(p_threshold=0.15)
# [I 2024-06-13 19:55:28,256] A new study created in RDB with name: mlops_exam_exercise-2024-06-13 19:55:28.220495
# /opt/conda/lib/python3.11/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
# ...
